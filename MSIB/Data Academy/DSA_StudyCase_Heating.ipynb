# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# conect colab to drive
from google.colab import drive
drive.mount('/content/drive/')

#Load data
path='/content/drive/MyDrive/DataSource/heatingOilTrainingset.csv'
df_dataset=pd.read_csv(path)
df_dataset
# Out:
# Drive already mounted at /content/drive/; to attempt to forcibly remount, call drive.mount("/content/drive/", force_remount=True).
#       Insulation  Temperature  Heating_Oil  Num_Occupants  Avg_Age  Home_Size
# 0              6           74          132              4     23.8          4
# 1             10           43          263              4     56.7          4
# 2              3           81          145              2     28.0          6
# 3              9           50          196              4     45.1          3
# 4              2           80          131              5     20.8          2
# ...          ...          ...          ...            ...      ...        ...
# 1213           7           56          264              5     58.2          5
# 1214           5           78          129              1     22.5          1
# 1215           5           77          138              3     26.8          1
# 1216           3           89          156              2     34.0          2
# 1217           7           59          273              1     61.4          5
#
# [1218 rows x 6 columns]

# %%
#data frame
df=pd.DataFrame(df_dataset)
df.head()
# Out:
#    Insulation  Temperature  Heating_Oil  Num_Occupants  Avg_Age  Home_Size
# 0           6           74          132              4     23.8          4
# 1          10           43          263              4     56.7          4
# 2           3           81          145              2     28.0          6
# 3           9           50          196              4     45.1          3
# 4           2           80          131              5     20.8          2

# %% [markdown]
# ## Business Understanding

# %% [markdown]
# kemungkinan algoritma estimasi yang akan digunakan
# 1.   Linear Regresion
# 2.   MLP Regresor (Artifical Neural Network)

# %% [markdown]
# ## Data Understanding
#
# insulation: This is a density rating, ranging from one to ten, indicating the thickness of
# each home’s insulation. A home with a density rating of one is poorly insulated, while a
# home with a density of ten has excellent insulation.
#  Temperature: This is the average outdoor ambient temperature at each home for the
# most recent year, measure in degree Fahrenheit.
#  Heating_Oil: This is the total number of units of heating oil purchased by the owner of
# each home in the most recent year.
#  Num_Occupants: This is the total number of occupants living in each home.
#  Avg_Age: This is the average age of those occupants.
#  Home_Size: This is a rating, on a scale of one to eight, of the home’s overall size. The
# higher the number, the larger the home

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1218 entries, 0 to 1217
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Insulation     1218 non-null   int64
#  1   Temperature    1218 non-null   int64
#  2   Heating_Oil    1218 non-null   int64
#  3   Num_Occupants  1218 non-null   int64
#  4   Avg_Age        1218 non-null   float64
#  5   Home_Size      1218 non-null   int64
# dtypes: float64(1), int64(5)
# memory usage: 57.2 KB

# %% [markdown]
# # Syarat dari penyelesaian problem estimasi: tidak ada variabel kategorik
#
# *   tidak perlu melakukan konversi data, disebabkan semua variable NUMERIK
# *   tidak perlu dilakukan handing masd

# %% [markdown]
# ## Linier Regresi

# %%
#menentukan input variable

x=df[['Insulation', 'Temperature', 'Num_Occupants', 'Avg_Age', 'Home_Size']]

#menentukan target variable
y=df['Heating_Oil']

# %%
#untuk split data kita menjadi training dan testing
from sklearn.model_selection import train_test_split
#untuk linier model
from sklearn.linear_model import LinearRegression
# untuk evaluasi model
from sklearn import metrics

# %%
#spilt data kita menjadi training dan testing
x_train, x_test, y_train, y_test=train_test_split(x,y, test_size=0.3, random_state=0)

# %%
x_train
# Out:
#       Insulation  Temperature  Num_Occupants  Avg_Age  Home_Size
# 579            6           75              5     24.1          3
# 1146           3           87              2     33.6          8
# 188            5           75              2     21.8          2
# 491            3           80              2     25.4          8
# 1217           7           59              1     61.4          5
# ...          ...          ...            ...      ...        ...
# 1033           3           82              5     27.0          3
# 763            5           76              2     41.3          7
# 835            3           80              4     23.3          4
# 559            7           55              3     61.6          7
# 684            4           75              4     28.4          8
#
# [852 rows x 5 columns]

# %%
regressor=LinearRegression()

#train model
model_reg = regressor.fit(x_train, y_train)

# %%
# Memprediksi dengan data test
y_pred_reg = model_reg.predict(x_test)

# %%
#evaluasi linier regression
print('r2_score :', metrics.r2_score(y_test, y_pred_reg))
# Out:
# r2_score : 0.8113322126382521

# %%
#membuat script MAPE
def mean_absolute_percentage_error(y_true, y_pred):
  y_true, y_pred = np.array(y_true), np.array(y_pred)
  return np.mean(np.abs((y_true-y_pred)/y_true))*100

# %%
print('MAPE :', mean_absolute_percentage_error(y_test, y_pred_reg))
# Out:
# MAPE : 7.845552048912459

# %% [markdown]
# ## Hasil evaluasi pada model Linier regresion
#
# Baik
#
# R2 menunjukkan nilai 0.81 mendekati 1, artinya untuk menjadi exellent hanya kurang 0.2
# Mape = 7.8. artinya tingkat error = 7.8% dan tingkat kesuksesan 92.2%

# %% [markdown]
# ## pemodelan dengan MLP Regresor (ANN = artifisial Neural Network)

# %%
from sklearn.neural_network import MLPRegressor

# %%
#objek MLP Regresor
mlp_reg=MLPRegressor()

#training model
model_mlp=mlp_reg.fit(x_train,y_train)

#predict model
y_pred_mlp=model_mlp.predict(x_test)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(

# %%
#evaluasi MLP regresor
print('r2_score :', metrics.r2_score(y_test, y_pred_mlp))
# Out:
# r2_score : 0.7643595749088299

# %%
print('MAPE :', mean_absolute_percentage_error(y_test, y_pred_mlp))
# Out:
# MAPE : 7.413856645369631

# %% [markdown]
# ## Hasil evaluasi pemodelan Neural network (MLP Regressor)
# 1.   R2 = 0.76 dalam kategori cukup baik
# 2.   Mape = 7,4% artinya ketepatan model =
#
# setelah melakukan tunning parameter, maka model terbaik diantara MLP regressor(dengan ditambahkan 3 hidden layer) dengan MAPE 5% artinya tingkat kegagalan 5% dan tingkat ke akuratan 95%. r2 =0.92

# %% [markdown]
# ## Implementasi MODEL ke data baru (Implementasi Model to Mesin Learning)
#
# Model yang akan kita gunakan adalah MLP regresor (AAN = Artificial Neural Network)

# %%
# New Costumer
path1='/content/drive/MyDrive/DataSource/heatingOilNewust.csv'
df_dataset1=pd.read_csv(path1)
df_dataset1
# Out:
#        Insulation  Temperature  Num_Occupants  Avg_Age  Home_Size
# 0               5           69             10     70.1          7
# 1               5           80              1     66.7          1
# 2               4           89              9     67.8          7
# 3               7           81              9     52.4          6
# 4               4           58              8     22.9          7
# ...           ...          ...            ...      ...        ...
# 42645           7           63              9     59.1          8
# 42646           7           84              1     43.6          5
# 42647           2           67              1     27.3          4
# 42648           8           58              1     65.7          3
# 42649           7           85              5     56.9          8
#
# [42650 rows x 5 columns]

# %%
df1 = pd.DataFrame(df_dataset1)
df1
# Out:
#        Insulation  Temperature  Num_Occupants  Avg_Age  Home_Size
# 0               5           69             10     70.1          7
# 1               5           80              1     66.7          1
# 2               4           89              9     67.8          7
# 3               7           81              9     52.4          6
# 4               4           58              8     22.9          7
# ...           ...          ...            ...      ...        ...
# 42645           7           63              9     59.1          8
# 42646           7           84              1     43.6          5
# 42647           2           67              1     27.3          4
# 42648           8           58              1     65.7          3
# 42649           7           85              5     56.9          8
#
# [42650 rows x 5 columns]

# %% [markdown]
# ## Data Preparation
#
# 1.   Select Input Variabel

# %%
x1=df1[['Insulation', 'Temperature', 'Num_Occupants', 'Avg_Age', 'Home_Size']]
x1
# Out:
#        Insulation  Temperature  Num_Occupants  Avg_Age  Home_Size
# 0               5           69             10     70.1          7
# 1               5           80              1     66.7          1
# 2               4           89              9     67.8          7
# 3               7           81              9     52.4          6
# 4               4           58              8     22.9          7
# ...           ...          ...            ...      ...        ...
# 42645           7           63              9     59.1          8
# 42646           7           84              1     43.6          5
# 42647           2           67              1     27.3          4
# 42648           8           58              1     65.7          3
# 42649           7           85              5     56.9          8
#
# [42650 rows x 5 columns]

# %% [markdown]
# ## Applying Model

# %%
y_predict_mlp = model_mlp.predict(x1)

# %%
y_predict_mlp
# Out:
# array([282.71599995, 235.66448032, 268.4924585 , ..., 124.17614822,
#        259.09507341, 253.67773771])

# %%
## mwngubah hasil pemodelan yang berbetuj aaray menjadi dataframe
df_y_predict_mlp = pd.DataFrame({'Prediction_HeatinngOil': y_predict_mlp}).round(2)

# %%
df_y_predict_mlp
# Out:
#        Prediction_HeatinngOil
# 0                      282.72
# 1                      235.66
# 2                      268.49
# 3                      237.66
# 4                      136.02
# ...                       ...
# 42645                  265.61
# 42646                  197.42
# 42647                  124.18
# 42648                  259.10
# 42649                  253.68
#
# [42650 rows x 1 columns]

# %%
## Menggabungkan Dataset NewCustomer dengan Hasil Predictnya
df_hasil_predict_mlp = pd.concat([df1, df_y_predict_mlp], sort=False, axis=1)
df_hasil_predict_mlp.head()
# Out:
#    Insulation  Temperature  Num_Occupants  Avg_Age  Home_Size  \
# 0           5           69             10     70.1          7
# 1           5           80              1     66.7          1
# 2           4           89              9     67.8          7
# 3           7           81              9     52.4          6
# 4           4           58              8     22.9          7
#
#    Prediction_HeatinngOil
# 0                  282.72
# 1                  235.66
# 2                  268.49
# 3                  237.66
# 4                  136.02

# %%
# Export to exel
#Export as download if in colab
from google.colab import files

file_predict_heatingOil=df_hasil_predict_mlp.to_excel('file_predict_heatingOil.xlsx', sheet_name='predict')
files.download('file_predict_heatingOil.xlsx')

# %% [markdown]
# ## Jumlah stock yang dibutuhkan selvi

# %%
newCust = df_hasil_predict_mlp['Prediction_HeatinngOil'].sum()
OldCust = df['Heating_Oil'].sum()

stock=newCust + OldCust

print('Kebutuhan Newcust :', newCust)
print('Kebutuhan Oldcust :', OldCust)

stock
# Out:
# Kebutuhan Newcust : 8440133.030000001
# Kebutuhan Oldcust : 240426
# 8680559.030000001
